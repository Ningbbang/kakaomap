# %%
import requests
import time
import pandas as pd

KAKAO_API_KEY = '15ea86f143832ac594738ff197575483'
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}

addresses = pd.read_csv('address_data.csv').loc[:5, 'address']

# %%
def get_coordinates(address):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    params = {"query": address}
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 200:
        documents = response.json().get("documents")
        if documents:
            return documents[0]["x"], documents[0]["y"]  # 경도, 위도
    return None, None

xs = []
ys = []

for addr in addresses:
    x, y = get_coordinates(addr)
    print(f"{addr} → 경도: {x}, 위도: {y}")
    xs.append(x)
    ys.append(y)
    time.sleep(0.3)  # 0.3초 대기 (API 제한 방지)

new_address = pd.DataFrame({'주소':addresses, 'x':xs, 'y':ys})
new_address
# Out:
# 경기도 오산시 경기대로 99-15 → 경도: 127.069824172632, 위도: 37.1330591988588
# 경기도 오산시 경기대로 99-18 → 경도: 127.069520169771, 위도: 37.1338885346837
# 경기도 오산시 오산로 91-5 → 경도: 127.067210468436, 위도: 37.1340236743957
# 경기도 오산시 동부대로 407-10 → 경도: 127.077226884027, 위도: 37.1389048391139
# 경기도 오산시 동부대로 429-9 → 경도: 127.07731417081, 위도: 37.139959834471
# 경기도 오산시 운암로 45 → 경도: 127.075870798538, 위도: 37.1502016754398
#                     주소                 x                 y
# 0   경기도 오산시 경기대로 99-15  127.069824172632  37.1330591988588
# 1   경기도 오산시 경기대로 99-18  127.069520169771  37.1338885346837
# 2     경기도 오산시 오산로 91-5  127.067210468436  37.1340236743957
# 3  경기도 오산시 동부대로 407-10  127.077226884027  37.1389048391139
# 4   경기도 오산시 동부대로 429-9   127.07731417081   37.139959834471
# 5       경기도 오산시 운암로 45  127.075870798538  37.1502016754398

# %%
import requests
import time
import pandas as pd

KAKAO_API_KEY = '15ea86f143832ac594738ff197575483'
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}

addresses = pd.read_csv('address_data.csv').loc[:5, 'address']


def get_coordinates(address):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    params = {"query": address}
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 200:
        documents = response.json().get("documents")
        if documents:
            return documents[0]["x"], documents[0]["y"]  # 경도, 위도
    return None, None

xs = []
ys = []

for addr in addresses:
    x, y = get_coordinates(addr)
    print(f"{addr} → 경도: {x}, 위도: {y}")
    xs.append(x)
    ys.append(y)
    time.sleep(0.3)  # 0.3초 대기 (API 제한 방지)

new_address = pd.DataFrame({'주소':addresses, 'x':xs, 'y':ys})
new_address
